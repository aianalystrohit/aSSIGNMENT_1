# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px


import warnings
warnings.filterwarnings('ignore')


plt.style.use("fivethirtyeight")
# %matplotlib inline

pd.set_option('display.max_columns', 30)

# %%
df = pd.read_csv("heart_failure_clinical_records_dataset.csv")

# %%
df
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...

# %%
df.describe()
# Out:
#               age     anaemia  creatinine_phosphokinase    diabetes  \
# count  299.000000  299.000000                299.000000  299.000000
# mean    60.833893    0.431438                581.839465    0.418060
# std     11.894809    0.496107                970.287881    0.494067
# min     40.000000    0.000000                 23.000000    0.000000
# 25%     51.000000    0.000000                116.500000    0.000000
# 50%     60.000000    0.000000                250.000000    0.000000
# 75%     70.000000    1.000000                582.000000    1.000000
# max     95.000000    1.000000               7861.000000    1.000000
#
#        ejection_fraction  high_blood_pressure      platelets  \
# count         299.000000           299.000000     299.000000
# mean           38.083612             0.351171  263358.029264
# std            11.834841             0.478136   97804.236869
# min            14.000000             0.000000   25100.000000
# ...

# %%
df.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1
# ...

# %%
df.sample()
# Out:
#      age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 91  60.0        0                       897         1                 45
#
#     high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 91                    0   297000.0               1.0           133    1
#
#     smoking  time  DEATH_EVENT
# 91        0    80            0

# %%
df.dtypes
# Out:
# age                         float64
# anaemia                       int64
# creatinine_phosphokinase      int64
# diabetes                      int64
# ejection_fraction             int64
# high_blood_pressure           int64
# platelets                   float64
# serum_creatinine            float64
# serum_sodium                  int64
# sex                           int64
# smoking                       int64
# time                          int64
# DEATH_EVENT                   int64
# dtype: object

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [age, anaemia, creatinine_phosphokinase, diabetes, ejection_fraction, high_blood_pressure, platelets, serum_creatinine, serum_sodium, sex, smoking, time, DEATH_EVENT]
# Index: []

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time',
#        'DEATH_EVENT'],
#       dtype='object')

# %%
df.columns.values
# Out:
# array(['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time',
#        'DEATH_EVENT'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       299 non-null    float64
#  1   anaemia                   299 non-null    int64
#  2   creatinine_phosphokinase  299 non-null    int64
#  3   diabetes                  299 non-null    int64
#  4   ejection_fraction         299 non-null    int64
#  5   high_blood_pressure       299 non-null    int64
#  6   platelets                 299 non-null    float64
#  7   serum_creatinine          299 non-null    float64
#  8   serum_sodium              299 non-null    int64
#  9   sex                       299 non-null    int64
#  10  smoking                   299 non-null    int64
#  11  time                      299 non-null    int64
#  12  DEATH_EVENT               299 non-null    int64
# dtypes: float64(3), int64(10)
# memory usage: 30.5 KB

# %%
cat_cols = [col for col in df.columns if df[col].dtype == 'object']
num_cols = [col for col in df.columns if df[col].dtype != 'object']

# %%
num_cols
# Out:
# ['age',
#  'anaemia',
#  'creatinine_phosphokinase',
#  'diabetes',
#  'ejection_fraction',
#  'high_blood_pressure',
#  'platelets',
#  'serum_creatinine',
#  'serum_sodium',
#  'sex',
#  'smoking',
#  'time',
#  'DEATH_EVENT']

# %%
df.isna().sum()
# Out:
# age                         0
# anaemia                     0
# creatinine_phosphokinase    0
# diabetes                    0
# ejection_fraction           0
# high_blood_pressure         0
# platelets                   0
# serum_creatinine            0
# serum_sodium                0
# sex                         0
# smoking                     0
# time                        0
# DEATH_EVENT                 0
# dtype: int64

# %%
df.columns
# Out:
# Index(['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time',
#        'DEATH_EVENT'],
#       dtype='object')

# %%
#univarriate analysis

# %%
plt.figure(figsize = (10,6))
sns.histplot(df['age'].dropna(), kde =True, color = 'orange')
plt.title('Distribution of age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
#insights

# %%
#Mean is around 60
#Most of the people are around 50-70
#Lesser no people

# %%
df.columns
# Out:
# Index(['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time',
#        'DEATH_EVENT'],
#       dtype='object')

# %%
df['DEATH_EVENT'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 294    False
# 295    False
# 296    False
# 297    False
# 298    False
# Name: DEATH_EVENT, Length: 299, dtype: bool

# %%
# EVents questions

# %%
#1.

# %%
#the distribution of age of people is normal distribution and having mean of 60.
df['age'].mean()
# Out:
# np.float64(60.83389297658862)

# %%
#2.

# %%
# Labeling data fields to Text value for easy interpretation of Visualization
data_eda = df.copy()

data_eda["sex"]                 = df["sex"] .map({1: "Male", 0: "Female"})
data_eda["diabetes"]            = df["diabetes"].map({1: "Yes", 0: "No"})
data_eda["anaemia"]             = df["anaemia"].map({1: "Yes", 0: "No"})
data_eda["high_blood_pressure"] = df["high_blood_pressure"].map({1: "Yes", 0: "No"})
data_eda["smoking"]             = df["smoking"].map({1: "Yes" , 0: "No"})
data_eda["DEATH_EVENT"]         = df["DEATH_EVENT"].map({1: "Yes", 0: "No"})

# %%
data_eda
# Out:
#       age anaemia  creatinine_phosphokinase diabetes  ejection_fraction  \
# 0    75.0      No                       582       No                 20
# 1    55.0      No                      7861       No                 38
# 2    65.0      No                       146       No                 20
# 3    50.0     Yes                       111       No                 20
# 4    65.0     Yes                       160      Yes                 20
# ..    ...     ...                       ...      ...                ...
# 294  62.0      No                        61      Yes                 38
# 295  55.0      No                      1820       No                 38
# 296  45.0      No                      2060      Yes                 60
# 297  45.0      No                      2413       No                 38
# 298  50.0      No                       196       No                 45
#
#     high_blood_pressure  platelets  serum_creatinine  serum_sodium     sex  \
# ...

# %%
filtered_data = data_eda[data_eda['DEATH_EVENT'] != 'No']  # Replace 'Y' with your actual value

plt.figure(figsize=(10, 6))
sns.violinplot(x='age', y='DEATH_EVENT', data=filtered_data)

plt.ylabel('Death Event (Yo)')

plt.xlabel('Age')
plt.title("Violin Plot: Age Distribution for 'Yes' Death Events")
plt.grid(True)
plt.show()

# %%
#Death rates are higher during 55 to 65 and minimal after 85+

# %%
#3

# %%
data_eda
# Out:
#       age anaemia  creatinine_phosphokinase diabetes  ejection_fraction  \
# 0    75.0      No                       582       No                 20
# 1    55.0      No                      7861       No                 38
# 2    65.0      No                       146       No                 20
# 3    50.0     Yes                       111       No                 20
# 4    65.0     Yes                       160      Yes                 20
# ..    ...     ...                       ...      ...                ...
# 294  62.0      No                        61      Yes                 38
# 295  55.0      No                      1820       No                 38
# 296  45.0      No                      2060      Yes                 60
# 297  45.0      No                      2413       No                 38
# 298  50.0      No                       196       No                 45
#
#     high_blood_pressure  platelets  serum_creatinine  serum_sodium     sex  \
# ...

# %%
data_eda['sex'].value_counts().plot.pie(autopct='%1.1f%%', colors=['lightcoral', 'lightgreen'], explode=(0, 0.1), startangle=90)
# Out:
# <Axes: ylabel='count'>

# %%
data_eda
# Out:
#       age anaemia  creatinine_phosphokinase diabetes  ejection_fraction  \
# 0    75.0      No                       582       No                 20
# 1    55.0      No                      7861       No                 38
# 2    65.0      No                       146       No                 20
# 3    50.0     Yes                       111       No                 20
# 4    65.0     Yes                       160      Yes                 20
# ..    ...     ...                       ...      ...                ...
# 294  62.0      No                        61      Yes                 38
# 295  55.0      No                      1820       No                 38
# 296  45.0      No                      2060      Yes                 60
# 297  45.0      No                      2413       No                 38
# 298  50.0      No                       196       No                 45
#
#     high_blood_pressure  platelets  serum_creatinine  serum_sodium     sex  \
# ...

# %%
#4
plt.figure(figsize = (10, 6))
sns.scatterplot(x = 'age', y='platelets', data=data_eda)
plt.xlabel('age')
plt.ylabel('platelets')
plt.title("scatter of blood urea by class")
plt.show()

# %%
data_eda
# Out:
#       age anaemia  creatinine_phosphokinase diabetes  ejection_fraction  \
# 0    75.0      No                       582       No                 20
# 1    55.0      No                      7861       No                 38
# 2    65.0      No                       146       No                 20
# 3    50.0     Yes                       111       No                 20
# 4    65.0     Yes                       160      Yes                 20
# ..    ...     ...                       ...      ...                ...
# 294  62.0      No                        61      Yes                 38
# 295  55.0      No                      1820       No                 38
# 296  45.0      No                      2060      Yes                 60
# 297  45.0      No                      2413       No                 38
# 298  50.0      No                       196       No                 45
#
#     high_blood_pressure  platelets  serum_creatinine  serum_sodium     sex  \
# ...

# %%
correlation = data_eda['serum_creatinine'].corr(data_eda['serum_sodium'])
print("Correlation between creatinine and sodium:", correlation)
# Out:
# Correlation between creatinine and sodium: -0.18909521009117392

# %%
#5
plt.scatter(df['serum_creatinine'], df['serum_sodium'])
plt.xlabel("Creatinine")
plt.ylabel("Sodium")
plt.title("Correlation between Creatinine and Sodium")
plt.show()

# %%
data_eda.columns
# Out:
# Index(['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time',
#        'DEATH_EVENT'],
#       dtype='object')

# %%
#6

# %%
a = pd.crosstab(data_eda['high_blood_pressure'], data_eda[ 'sex'])
a.plot(kind = 'bar', stacked = True, color = ['#6DA7DE', '#FF9A8B'], figsize = (10, 6))

plt.xlabel('sex')
plt.ylabel("shigh_blood_pressure")
plt.legend(title="sex")
plt.title("high_blood_pressure and sex")
plt.show()

# %%
#7

# %%
#smoking habit and occuranc of heart failure

# %%
data_eda.columns
# Out:
# Index(['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time',
#        'DEATH_EVENT'],
#       dtype='object')

# %%
data_eda
# Out:
#       age anaemia  creatinine_phosphokinase diabetes  ejection_fraction  \
# 0    75.0      No                       582       No                 20
# 1    55.0      No                      7861       No                 38
# 2    65.0      No                       146       No                 20
# 3    50.0     Yes                       111       No                 20
# 4    65.0     Yes                       160      Yes                 20
# ..    ...     ...                       ...      ...                ...
# 294  62.0      No                        61      Yes                 38
# 295  55.0      No                      1820       No                 38
# 296  45.0      No                      2060      Yes                 60
# 297  45.0      No                      2413       No                 38
# 298  50.0      No                       196       No                 45
#
#     high_blood_pressure  platelets  serum_creatinine  serum_sodium     sex  \
# ...

# %%
a = pd.crosstab(data_eda['smoking'], data_eda[ 'DEATH_EVENT'])
a.plot(kind = 'bar', stacked = True, color = ['#6DA7DE', '#FF9A8B'], figsize = (10, 6))

plt.xlabel('smoking')
plt.ylabel("DEATH_EVENT")
plt.legend(title="smoking")
plt.title("Smoking and DEATH_EVENT")
plt.show()

# %%
data_eda.columns
# Out:
# Index(['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time',
#        'DEATH_EVENT'],
#       dtype='object')

# %%
#8

# %%
filtered_data = data_eda[data_eda['DEATH_EVENT'] != 'No']  # Replace 'Y' with your actual value

plt.figure(figsize=(10, 6))
sns.violinplot(x='age', y='DEATH_EVENT', data=filtered_data)

plt.ylabel('Death Event (Yo)')

plt.xlabel('Age')
plt.title("Violin Plot: Age Distribution for 'Yes' Death Events")
plt.grid(True)
plt.show()

# %%
#yes most of the death are happening near to 60ties

# %%
#9

# %%
plt.figure(figsize=(16, 10))
data_eda.boxplot(by='diabetes', column=['ejection_fraction'])
plt.ylabel('Ejection Fraction')
plt.xlabel('Diabetes')
plt.show()

# %%
#10

# %%
data_eda.columns
# Out:
# Index(['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time',
#        'DEATH_EVENT'],
#       dtype='object')

# %%
data_eda.boxplot(by='DEATH_EVENT', column=['serum_creatinine'])
plt.ylabel('serum_creatinine')
plt.xlabel('DEATH_EVENT')
plt.show()
